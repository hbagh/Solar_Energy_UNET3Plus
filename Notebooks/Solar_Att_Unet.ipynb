# %%
# %reset -f

# %%
import tensorflow as tf
import os
import random
import numpy as np
from tqdm import tqdm 
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
from skimage import io  # for reading TIFF images
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, LearningRateScheduler, EarlyStopping
from skimage import io  # for reading TIFF images
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.losses import *
from keras import backend as K

# %%
# Set the desired number of patches
desired_num_patches = 7566

# Your data directories
dsm_images_dir = 'DSM_Clip_Patches'
solar_map_dir = 'Solar_Clip_Patches'

# Get the list of file names in the directories without sorting
dsm_files = os.listdir(dsm_images_dir)
solar_map_files = os.listdir(solar_map_dir)

# %%
# Initialize empty lists to store data
x_train_list = []
solar_values_list = []


# Loop through each patch with tqdm for progress bars
for i in tqdm(range(min(desired_num_patches, len(dsm_files))), desc='Loading Patches'):
    # Get file names for the current index
    dsm_file = dsm_files[i]
    solar_map_file = solar_map_files[i]
    
    # Load images
    dsm_image = io.imread(os.path.join(dsm_images_dir, dsm_file))
    solar_map = io.imread(os.path.join(solar_map_dir, solar_map_file))

    # Normalize the data using min-max scaling for DSM
    if np.min(dsm_image) != np.max(dsm_image):
        dsm_image_normalized = (dsm_image - np.min(dsm_image)) / (np.max(dsm_image) - np.min(dsm_image))
    else:
        dsm_image_normalized = dsm_image

    # Ensure the shape matches the specified format
    dsm_image_normalized = np.expand_dims(dsm_image_normalized, axis=-1)

    # Expand dimensions for solar map to match the channel dimension
    solar_map = np.expand_dims(solar_map, axis=-1)

    x_train_list.append(dsm_image_normalized)
    solar_values_list.append(solar_map)

    # Break the loop when desired_num_patches is reached
    if len(x_train_list) >= desired_num_patches:
        break

# Combine all patches into single arrays
x_data_dsm = np.stack(x_train_list)
solar_values = np.stack(solar_values_list)

# Ensure the solar values have the correct shape
solar_values = np.squeeze(solar_values, axis=(3,))

# Normalize solar values using min-max scaling
min_solar = np.min(solar_values)
max_solar = np.max(solar_values)
solar_scaled = (solar_values - min_solar) / (max_solar - min_solar)

# Reshape scaled solar values for compatibility with the model
solar_normalized = np.expand_dims(solar_scaled, axis=-1)

# Split the data into training, validation, and test sets
x_train, x_test, y_train, y_test = train_test_split(x_data_dsm, solar_normalized, test_size=0.20, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.20, random_state=42)

# Print the shapes of the datasets
print('x_train:', x_train.shape)
print('y_train:', y_train.shape)
print('x_val shape:', x_val.shape)
print('y_val shape:', y_val.shape)
print('x_test shape:', x_test.shape)
print('y_test shape:', y_test.shape)

input_shape = x_train.shape[1:]
# Out:
# Loading Patches: 100%|█████████▉| 7565/7566 [00:43<00:00, 174.54it/s]
# x_train: (4841, 128, 128, 1)
# y_train: (4841, 128, 128, 1)
# x_val shape: (1211, 128, 128, 1)
# y_val shape: (1211, 128, 128, 1)
# x_test shape: (1514, 128, 128, 1)
# y_test shape: (1514, 128, 128, 1)

# %%
'''
  Convolutional block with set parameters and activation layer after
'''

def convBlock(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    #conv = ZeroPadding2D((1,1))(input)
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
  else:
    #conv = ZeroPadding2D((1,1))(input)
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)

  conv = Activation(act)(conv)
  return conv

# %%
'''
  Convolutional block with two conv layers and two activation layers
'''

def convBlock2(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)
  else:
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)

  return conv

# %%
'''
  Attention block/mechanism
'''
def attention_block(x, gating, inter_shape, drop_rate=0.25):
   
    # Find shape of inputs
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

    ## Process x vector and gating signal
    # x vector input and processing
    theta_x = Conv2D(inter_shape, kernel_size = 1, strides = 1, padding='same', kernel_initializer='he_normal', activation=None)(x)
    theta_x = MaxPooling2D((2,2))(theta_x)
    shape_theta_x = K.int_shape(theta_x)

    # gating signal ""
    phi_g = Conv2D(inter_shape, kernel_size = 1, strides = 1, padding='same', kernel_initializer='he_normal', activation=None)(gating)
    shape_phi_g = K.int_shape(phi_g)

    # Add components
    concat_xg = add([phi_g, theta_x])
    act_xg = Activation('relu')(concat_xg)

    # Apply convolution
    psi = Conv2D(1, kernel_size = 1, strides = 1, padding='same', kernel_initializer='he_normal', activation=None)(act_xg)

    # Apply sigmoid activation
    sigmoid_xg = Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)

    
    # UpSample and resample to correct size
    upsample_psi = UpSampling2D(interpolation='nearest', size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)
    upsample_psi = Lambda(lambda x: K.tile(x, [1, 1, 1, shape_x[3]]))(upsample_psi)
    y = multiply([upsample_psi, x])

    return y

# %%
'''
  Attention U-Net model
'''

def UNetAM(trained_weights=None, input_size=(128, 128, 1), drop_rate=0.25, lr=0.0005, filter_base=16):
    # Input layer
    inputs = Input(input_size)

    ## Contraction phase
    conv = convBlock2(inputs, filter_base, 3)
    # conv0 = Dropout(drop_rate)(conv0)

    # Modify the number of input channels to match your data
    conv0 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv0 = convBlock2(conv0, 2 * filter_base, 3)

    pool0 = MaxPooling2D(pool_size=(2, 2))(conv0)
    conv1 = convBlock2(pool0, 4 * filter_base, 3)
    # conv1 = Dropout(drop_rate)(conv1)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = convBlock2(pool1, 8 * filter_base, 3)
    # conv2 = Dropout(drop_rate)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = convBlock2(pool2, 16 * filter_base, 3)
    # conv3 = Dropout(drop_rate)(conv3)

    ## Expansion phase
    up4 = (Conv2DTranspose(8 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv3))
    merge4 = attention_block(conv2, conv3, 8 * filter_base, drop_rate)  # Attention gate
    conv4 = concatenate([up4, merge4])
    conv4 = convBlock2(conv4, 8 * filter_base, 3)

    up5 = (Conv2DTranspose(4 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv4))
    merge5 = attention_block(conv1, conv4, 4 * filter_base, drop_rate)  # Attention gate
    conv5 = concatenate([up5, merge5])
    conv5 = convBlock2(conv5, 4 * filter_base, 3)

    up6 = (Conv2DTranspose(2 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv5))
    merge6 = attention_block(conv0, conv5, 2 * filter_base, drop_rate)  # Attention gate
    conv6 = concatenate([up6, merge6])
    conv6 = convBlock2(conv6, 2 * filter_base, 3)

    up7 = (Conv2DTranspose(1 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv6))
    merge7 = attention_block(conv, conv6, 1 * filter_base, drop_rate)  # Attention gate
    conv7 = concatenate([up7, merge7])
    conv7 = concatenate([up7, conv])
    conv7 = convBlock2(conv7, 1 * filter_base, 3)

    ## Output layer
    # Modify the number of output channels to match your task
    out = convBlock(conv7, 1, 1, act='sigmoid')

    model = Model(inputs, out)

    model.compile(optimizer=adam_v2.Adam(learning_rate=lr), loss=mean_squared_error, metrics=[ 'mae'])

    if trained_weights is not None:
        model.load_weights(trained_weights)

    return model

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-3
    print('Learning rate: ', lr)
    return lr

# %%
lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

# %%
# Print model layers and number of parameters
UNetAM().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 16  160         ['input_1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 128, 128, 16  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  2320        ['activation[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 128, 128, 16  0           ['conv2d_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   4640        ['max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (None, 64, 64, 32)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   9248        ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 64, 64, 32)   0           ['conv2d_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  activation_4 (Activation)      (None, 32, 32, 64)   0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 64)   36928       ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 32, 32, 64)   0           ['conv2d_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  activation_6 (Activation)      (None, 16, 16, 128)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 128)  147584      ['activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 16, 16, 128)  0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    295168      ['max_pooling2d_3[0][0]']
#
#  activation_8 (Activation)      (None, 8, 8, 256)    0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    590080      ['activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 8, 8, 256)    0           ['conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  16512       ['activation_7[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 128)    32896       ['activation_9[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 128)   0           ['conv2d_10[0][0]']
#
#  add (Add)                      (None, 8, 8, 128)    0           ['conv2d_11[0][0]',
#                                                                   'max_pooling2d_4[0][0]']
#
#  activation_10 (Activation)     (None, 8, 8, 128)    0           ['add[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 1)      129         ['activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 8, 8, 1)      0           ['conv2d_12[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 1)    0           ['activation_11[0][0]']
#
#  lambda (Lambda)                (None, 16, 16, 128)  0           ['up_sampling2d[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  131200     ['activation_9[0][0]']
#  ose)
#
#  multiply (Multiply)            (None, 16, 16, 128)  0           ['lambda[0][0]',
#                                                                   'activation_7[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'multiply[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 128)  295040      ['concatenate[0][0]']
#
#  activation_12 (Activation)     (None, 16, 16, 128)  0           ['conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_12[0][0]']
#
#  activation_13 (Activation)     (None, 16, 16, 128)  0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   4160        ['activation_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 64)   8256        ['activation_13[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_15[0][0]']
#
#  add_1 (Add)                    (None, 16, 16, 64)   0           ['conv2d_16[0][0]',
#                                                                   'max_pooling2d_5[0][0]']
#
#  activation_14 (Activation)     (None, 16, 16, 64)   0           ['add_1[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 1)    65          ['activation_14[0][0]']
#
#  activation_15 (Activation)     (None, 16, 16, 1)    0           ['conv2d_17[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 1)   0           ['activation_15[0][0]']
#
#  lambda_1 (Lambda)              (None, 32, 32, 64)   0           ['up_sampling2d_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  32832       ['activation_13[0][0]']
#  spose)
#
#  multiply_1 (Multiply)          (None, 32, 32, 64)   0           ['lambda_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 64)   73792       ['concatenate_1[0][0]']
#
#  activation_16 (Activation)     (None, 32, 32, 64)   0           ['conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_16[0][0]']
#
#  activation_17 (Activation)     (None, 32, 32, 64)   0           ['conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 32)   1056        ['activation_3[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 32)   2080        ['activation_17[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 32)  0           ['conv2d_20[0][0]']
#
#  add_2 (Add)                    (None, 32, 32, 32)   0           ['conv2d_21[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  activation_18 (Activation)     (None, 32, 32, 32)   0           ['add_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 1)    33          ['activation_18[0][0]']
#
#  activation_19 (Activation)     (None, 32, 32, 1)    0           ['conv2d_22[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 1)   0           ['activation_19[0][0]']
#
#  lambda_2 (Lambda)              (None, 64, 64, 32)   0           ['up_sampling2d_2[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  8224        ['activation_17[0][0]']
#  spose)
#
#  multiply_2 (Multiply)          (None, 64, 64, 32)   0           ['lambda_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_2[0][0]']
#
#  activation_20 (Activation)     (None, 64, 64, 32)   0           ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_20[0][0]']
#
#  activation_21 (Activation)     (None, 64, 64, 32)   0           ['conv2d_24[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  2064       ['activation_21[0][0]']
#  spose)                         )
#
#  concatenate_4 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 128, 128, 16  4624        ['concatenate_4[0][0]']
#                                 )
#
#  activation_24 (Activation)     (None, 128, 128, 16  0           ['conv2d_28[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 128, 128, 16  2320        ['activation_24[0][0]']
#                                 )
#
#  activation_25 (Activation)     (None, 128, 128, 16  0           ['conv2d_29[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 128, 128, 1)  17          ['activation_25[0][0]']
#
#  activation_26 (Activation)     (None, 128, 128, 1)  0           ['conv2d_30[0][0]']
#
# ==================================================================================================
# Total params: 2,006,004
# Trainable params: 2,006,004
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train Attention U-Net with generator
checkpointer = tf.keras.callbacks.ModelCheckpoint('Solar-unet-attention-3d.hdf5',monitor='val_mae', verbose=1, save_best_only=True)

callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=300, monitor='val_mae'),
        tf.keras.callbacks.TensorBoard(log_dir='logs'),
        checkpointer]
model_attention_unet = UNetAM(lr=0.0001, filter_base=16)

# train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)
import time

start_time = time.time()

# Your model training code here
results = model_attention_unet.fit(x_train, y_train, validation_data=(x_val, y_val), batch_size=32, epochs=300,callbacks=callbacks)

end_time = time.time()
training_time_seconds = end_time - start_time
training_time_minutes = training_time_seconds / 60

print("Training completed in {:.2f} seconds ({:.2f} minutes)".format(training_time_seconds, training_time_minutes))
# Out:
# Epoch 1/300
# 152/152 [==============================] - ETA: 0s - loss: 0.0694 - mae: 0.2181
# Epoch 1: val_mae improved from inf to 0.20051, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 10s 43ms/step - loss: 0.0694 - mae: 0.2181 - val_loss: 0.0636 - val_mae: 0.2005
# Epoch 2/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0582 - mae: 0.1886
# Epoch 2: val_mae improved from 0.20051 to 0.19029, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.0582 - mae: 0.1885 - val_loss: 0.0599 - val_mae: 0.1903
# Epoch 3/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0544 - mae: 0.1792
# Epoch 3: val_mae improved from 0.19029 to 0.18187, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.0544 - mae: 0.1792 - val_loss: 0.0559 - val_mae: 0.1819
# Epoch 4/300
# 152/152 [==============================] - ETA: 0s - loss: 0.0506 - mae: 0.1695
# Epoch 4: val_mae improved from 0.18187 to 0.17267, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.0506 - mae: 0.1695 - val_loss: 0.0515 - val_mae: 0.1727
# Epoch 5/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0475 - mae: 0.1631
# Epoch 5: val_mae improved from 0.17267 to 0.16887, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 36ms/step - loss: 0.0475 - mae: 0.1632 - val_loss: 0.0495 - val_mae: 0.1689
# Epoch 6/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0456 - mae: 0.1577
# Epoch 6: val_mae improved from 0.16887 to 0.16078, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 36ms/step - loss: 0.0457 - mae: 0.1578 - val_loss: 0.0454 - val_mae: 0.1608
# Epoch 7/300
# 152/152 [==============================] - ETA: 0s - loss: 0.0425 - mae: 0.1509
# Epoch 7: val_mae improved from 0.16078 to 0.15086, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.0425 - mae: 0.1509 - val_loss: 0.0426 - val_mae: 0.1509
# Epoch 8/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0393 - mae: 0.1428
# Epoch 8: val_mae improved from 0.15086 to 0.14805, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 36ms/step - loss: 0.0393 - mae: 0.1428 - val_loss: 0.0401 - val_mae: 0.1481
# Epoch 9/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0375 - mae: 0.1381
# Epoch 9: val_mae improved from 0.14805 to 0.14375, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.0375 - mae: 0.1381 - val_loss: 0.0375 - val_mae: 0.1437
# Epoch 10/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.1368
# Epoch 10: val_mae improved from 0.14375 to 0.14323, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.0370 - mae: 0.1368 - val_loss: 0.0415 - val_mae: 0.1432
# Epoch 11/300
# 152/152 [==============================] - ETA: 0s - loss: 0.0352 - mae: 0.1324
# Epoch 11: val_mae improved from 0.14323 to 0.13887, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 36ms/step - loss: 0.0352 - mae: 0.1324 - val_loss: 0.0388 - val_mae: 0.1389
# Epoch 12/300
# 152/152 [==============================] - ETA: 0s - loss: 0.0331 - mae: 0.1280
# Epoch 12: val_mae improved from 0.13887 to 0.12690, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.0331 - mae: 0.1280 - val_loss: 0.0341 - val_mae: 0.1269
# Epoch 13/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0309 - mae: 0.1224
# Epoch 13: val_mae improved from 0.12690 to 0.12406, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 36ms/step - loss: 0.0309 - mae: 0.1223 - val_loss: 0.0333 - val_mae: 0.1241
# Epoch 14/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0300 - mae: 0.1200
# Epoch 14: val_mae did not improve from 0.12406
# 152/152 [==============================] - 5s 36ms/step - loss: 0.0300 - mae: 0.1200 - val_loss: 0.0330 - val_mae: 0.1247
# Epoch 15/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0298 - mae: 0.1191
# Epoch 15: val_mae did not improve from 0.12406
# 152/152 [==============================] - 5s 36ms/step - loss: 0.0298 - mae: 0.1190 - val_loss: 0.0342 - val_mae: 0.1248
# Epoch 16/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0273 - mae: 0.1135
# Epoch 16: val_mae improved from 0.12406 to 0.12158, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.0272 - mae: 0.1134 - val_loss: 0.0307 - val_mae: 0.1216
# Epoch 17/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0268 - mae: 0.1122
# Epoch 17: val_mae improved from 0.12158 to 0.11537, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.0268 - mae: 0.1122 - val_loss: 0.0298 - val_mae: 0.1154
# Epoch 18/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0266 - mae: 0.1110
# Epoch 18: val_mae did not improve from 0.11537
# 152/152 [==============================] - 5s 36ms/step - loss: 0.0266 - mae: 0.1110 - val_loss: 0.0360 - val_mae: 0.1236
# Epoch 19/300
# 152/152 [==============================] - ETA: 0s - loss: 0.0248 - mae: 0.1072
# Epoch 19: val_mae did not improve from 0.11537
# 152/152 [==============================] - 5s 36ms/step - loss: 0.0248 - mae: 0.1072 - val_loss: 0.0341 - val_mae: 0.1224
# Epoch 20/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0276 - mae: 0.1134
# Epoch 20: val_mae did not improve from 0.11537
# 152/152 [==============================] - 5s 36ms/step - loss: 0.0276 - mae: 0.1134 - val_loss: 0.0332 - val_mae: 0.1266
# Epoch 21/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0241 - mae: 0.1056
# Epoch 21: val_mae did not improve from 0.11537
# 152/152 [==============================] - 5s 36ms/step - loss: 0.0241 - mae: 0.1056 - val_loss: 0.0416 - val_mae: 0.1356
# Epoch 22/300
# 152/152 [==============================] - ETA: 0s - loss: 0.0230 - mae: 0.1030
# Epoch 22: val_mae improved from 0.11537 to 0.11285, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.0230 - mae: 0.1030 - val_loss: 0.0290 - val_mae: 0.1128
# Epoch 23/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0225 - mae: 0.1011
# Epoch 23: val_mae did not improve from 0.11285
# 152/152 [==============================] - 5s 36ms/step - loss: 0.0225 - mae: 0.1011 - val_loss: 0.0324 - val_mae: 0.1202
# Epoch 24/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0225 - mae: 0.1010
# Epoch 24: val_mae did not improve from 0.11285
# 152/152 [==============================] - 5s 36ms/step - loss: 0.0225 - mae: 0.1010 - val_loss: 0.0323 - val_mae: 0.1173
# Epoch 25/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0202 - mae: 0.0959
# Epoch 25: val_mae improved from 0.11285 to 0.10962, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.0202 - mae: 0.0959 - val_loss: 0.0281 - val_mae: 0.1096
# Epoch 26/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0189 - mae: 0.0924
# Epoch 26: val_mae improved from 0.10962 to 0.10875, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.0189 - mae: 0.0924 - val_loss: 0.0276 - val_mae: 0.1088
# Epoch 27/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0188 - mae: 0.0923
# Epoch 27: val_mae did not improve from 0.10875
# 152/152 [==============================] - 5s 36ms/step - loss: 0.0188 - mae: 0.0923 - val_loss: 0.0355 - val_mae: 0.1209
# Epoch 28/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0221 - mae: 0.0998
# Epoch 28: val_mae did not improve from 0.10875
# 152/152 [==============================] - 5s 36ms/step - loss: 0.0221 - mae: 0.0998 - val_loss: 0.0313 - val_mae: 0.1123
# Epoch 29/300
# 152/152 [==============================] - ETA: 0s - loss: 0.0173 - mae: 0.0885
# Epoch 29: val_mae improved from 0.10875 to 0.10423, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.0173 - mae: 0.0885 - val_loss: 0.0262 - val_mae: 0.1042
# Epoch 30/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0164 - mae: 0.0859
# Epoch 30: val_mae did not improve from 0.10423
# 152/152 [==============================] - 5s 36ms/step - loss: 0.0164 - mae: 0.0859 - val_loss: 0.0267 - val_mae: 0.1055
# Epoch 31/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0170 - mae: 0.0870
# Epoch 31: val_mae improved from 0.10423 to 0.10389, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 36ms/step - loss: 0.0169 - mae: 0.0870 - val_loss: 0.0269 - val_mae: 0.1039
# Epoch 32/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0152 - mae: 0.0824
# Epoch 32: val_mae improved from 0.10389 to 0.10205, saving model to Solar-unet-attention-3d.hdf5
# 152/152 [==============================] - 6s 37ms/step - loss: 0.
val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0323 - val_loss: 0.0225 - val_mae: 0.0789
# Epoch 285/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0323
# Epoch 285: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0322 - val_loss: 0.0224 - val_mae: 0.0790
# Epoch 286/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0322
# Epoch 286: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0322 - val_loss: 0.0225 - val_mae: 0.0791
# Epoch 287/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0322
# Epoch 287: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0322 - val_loss: 0.0225 - val_mae: 0.0788
# Epoch 288/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0321
# Epoch 288: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0321 - val_loss: 0.0224 - val_mae: 0.0791
# Epoch 289/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0321
# Epoch 289: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0321 - val_loss: 0.0225 - val_mae: 0.0787
# Epoch 290/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0322
# Epoch 290: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0322 - val_loss: 0.0224 - val_mae: 0.0788
# Epoch 291/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0321
# Epoch 291: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0321 - val_loss: 0.0225 - val_mae: 0.0785
# Epoch 292/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0321
# Epoch 292: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0321 - val_loss: 0.0223 - val_mae: 0.0786
# Epoch 293/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0321
# Epoch 293: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0321 - val_loss: 0.0224 - val_mae: 0.0791
# Epoch 294/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0323
# Epoch 294: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0323 - val_loss: 0.0224 - val_mae: 0.0783
# Epoch 295/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0324
# Epoch 295: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0324 - val_loss: 0.0222 - val_mae: 0.0786
# Epoch 296/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0322
# Epoch 296: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0322 - val_loss: 0.0225 - val_mae: 0.0784
# Epoch 297/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0321
# Epoch 297: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0321 - val_loss: 0.0223 - val_mae: 0.0792
# Epoch 298/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0322
# Epoch 298: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0322 - val_loss: 0.0225 - val_mae: 0.0782
# Epoch 299/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0324
# Epoch 299: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 67ms/step - loss: 0.0030 - mae: 0.0324 - val_loss: 0.0223 - val_mae: 0.0784
# Epoch 300/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0322
# Epoch 300: val_mae did not improve from 0.07782
# 152/152 [==============================] - 10s 68ms/step - loss: 0.0030 - mae: 0.0322 - val_loss: 0.0224 - val_mae: 0.0781
# Training completed in 2548.79 seconds (42.48 minutes)

# %%
# Plot the loss diagram
plt.figure(figsize=(10, 6))
plt.plot(results.history['loss'], label='Training Loss')
plt.plot(results.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('Training and Validation Loss.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
# Plot the accuracy diagram
plt.figure(figsize=(10, 6))
plt.plot(results.history['mae'], label='Mean Absolute Error')
plt.plot(results.history['val_mae'], label='Validation Mean Absolute Error')
plt.title('Training and Validation Mean Absolute Error')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.savefig('Training and Validation Mean Absolute Error.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
solar_max = np.max(solar_values)
solar_min = np.min(solar_values)
print(solar_max)
print(solar_min)
# Out:
# 1045434.44
# 0.0

# %%
start_time = time.time()
y_pred1 = model_attention_unet.predict(x_test)

end_time = time.time()
x_test_time_seconds = end_time - start_time
x_test_time_minutes = x_test_time_seconds / 60

print("x_test_Prediction completed in {:.2f} seconds ({:.2f} minutes)".format(x_test_time_seconds, x_test_time_minutes))
# Out:
# 48/48 [==============================] - 1s 17ms/step
# x_test_Prediction completed in 1.13 seconds (0.02 minutes)

# %%
y_pred1 = model_attention_unet.predict(x_test)
y_pred = y_pred1 * (solar_max - solar_min) + solar_min
y_test2 = y_test * (solar_max - solar_min) + solar_min
# Out:
# 48/48 [==============================] - 1s 8ms/step

# %%
# Flatten the arrays
y_test2_flat = y_test2.flatten()
y_pred_flat = y_pred.flatten()

# Calculate R^2
r2 = r2_score(y_test2_flat, y_pred_flat)

# %%
start_time = time.time()
y_train_pred =  model_attention_unet.predict(x_train)

end_time = time.time()
x_train_time_seconds = end_time - start_time
x_train_time_minutes = x_train_time_seconds / 60

print("x_train_Prediction completed in {:.2f} seconds ({:.2f} minutes)".format(x_train_time_seconds,x_train_time_minutes))
# Out:
# 152/152 [==============================] - 1s 8ms/step
# x_train_Prediction completed in 1.72 seconds (0.03 minutes)

# %%
start_time = time.time()
y_train_pred =  model_attention_unet.predict(x_data_dsm)

end_time = time.time()
x_data_dsm_time_seconds = end_time - start_time
x_data_dsm_time_minutes = x_data_dsm_time_seconds / 60

print("x_data_dsm_Prediction completed in {:.2f} seconds ({:.2f} minutes)".format(x_data_dsm_time_seconds,x_data_dsm_time_minutes))
# Out:
# 237/237 [==============================] - 2s 9ms/step
# x_data_dsm_Prediction completed in 2.77 seconds (0.05 minutes)

# %%
# Calculate R^2 for training data
y_train_pred = model_attention_unet.predict(x_train)
y_train_pred2 = y_train_pred * (solar_max - solar_min) + solar_min
y_train2 = y_train * (solar_max - solar_min) + solar_min
# # Flatten the arrays
y_train_pred2_flat = y_train_pred2.flatten()
y_train2_flat = y_train2.flatten()

# Calculate R^2 for training data
r2_train = r2_score(y_train2_flat, y_train_pred2_flat)
# Out:
# 152/152 [==============================] - 1s 9ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LogNorm

# Reshape arrays if needed
y_test2 = y_test2_flat
y_pred = y_pred_flat

# Create a figure and axis with a larger size
plt.figure(figsize=(10, 6))

# Create a 2D histogram to calculate point density
hist, x_edges, y_edges = np.histogram2d(y_test2, y_pred, bins=(50, 50), density=True)

# Calculate the point density for each point
density = hist[np.clip(np.digitize(y_test2, x_edges) - 1, 0, hist.shape[0] - 1),
               np.clip(np.digitize(y_pred, y_edges) - 1, 0, hist.shape[1] - 1)]

# Use logarithmic scaling for density values
log_density = np.log1p(density)

# Scatter plot with color based on log-scaled density and inverse hot colormap
scatter = plt.scatter(y_pred, y_test2, c=log_density, cmap='jet', s=10, norm=LogNorm())

# Plot true regression line
regression_line = np.polyfit(y_test2, y_pred, 1)
poly_y = np.polyval(regression_line, y_test2)
plt.plot(y_test2, poly_y, color='orange', label='Regression Line')

# Plot ideal line (y = x)
plt.plot(y_test2, y_test2, color='purple', linestyle='--', label='Ideal Line')

# Add labels, legend, and colorbar with larger font sizes
plt.xlabel('Predicted Values', fontsize=14)
plt.ylabel('Referenced AGB', fontsize=14)
plt.title('Scatter Plot of Predicted vs Referenced AGB with R²', fontsize=16)
plt.legend(fontsize=12)

# Annotate R^2 value creatively
annotation_text = f'R² = {r2:.2f}'
plt.annotate(annotation_text, xy=(0.95, 0.05), xycoords='axes fraction',
             fontsize=12, ha='right', va='bottom', color='green', bbox=dict(boxstyle="round,pad=0.1", alpha=0.2))

# Save the plot as a high-quality PNG image with larger font sizes
plt.savefig('scatter_plot_density_colored_log_inverse_hot.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# C:\Users\Green\AppData\Local\Temp\ipykernel_1416\4216629586.py:45: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('scatter_plot_density_colored_log_inverse_hot.png', dpi=300, bbox_inches='tight')
# c:\Users\Green\anaconda3\envs\tf-gpu\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
