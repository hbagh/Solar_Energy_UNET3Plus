# %%
# %reset -f

# %%
import tensorflow as tf
import os
import random
import numpy as np
from tqdm import tqdm 
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
from skimage import io  # for reading TIFF images
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, LearningRateScheduler, EarlyStopping
import time

# %%
# Set the desired number of patches
desired_num_patches = 7566

# Your data directories
dsm_images_dir = 'DSM_Clip_Patches'
solar_map_dir = 'Solar_Clip_Patches'

# Get the list of file names in the directories without sorting
dsm_files = os.listdir(dsm_images_dir)
solar_map_files = os.listdir(solar_map_dir)

# %%
# Initialize empty lists to store data
x_train_list = []
solar_values_list = []


# Loop through each patch with tqdm for progress bars
for i in tqdm(range(min(desired_num_patches, len(dsm_files))), desc='Loading Patches'):
    # Get file names for the current index
    dsm_file = dsm_files[i]
    solar_map_file = solar_map_files[i]
    
    # Load images
    dsm_image = io.imread(os.path.join(dsm_images_dir, dsm_file))
    solar_map = io.imread(os.path.join(solar_map_dir, solar_map_file))

    # Normalize the data using min-max scaling for DSM
    if np.min(dsm_image) != np.max(dsm_image):
        dsm_image_normalized = (dsm_image - np.min(dsm_image)) / (np.max(dsm_image) - np.min(dsm_image))
    else:
        dsm_image_normalized = dsm_image

    # Ensure the shape matches the specified format
    dsm_image_normalized = np.expand_dims(dsm_image_normalized, axis=-1)

    # Expand dimensions for solar map to match the channel dimension
    solar_map = np.expand_dims(solar_map, axis=-1)

    x_train_list.append(dsm_image_normalized)
    solar_values_list.append(solar_map)

    # Break the loop when desired_num_patches is reached
    if len(x_train_list) >= desired_num_patches:
        break

# Combine all patches into single arrays
x_data_dsm = np.stack(x_train_list)
solar_values = np.stack(solar_values_list)

# Ensure the solar values have the correct shape
solar_values = np.squeeze(solar_values, axis=(3,))

# Normalize solar values using min-max scaling
min_solar = np.min(solar_values)
max_solar = np.max(solar_values)
solar_scaled = (solar_values - min_solar) / (max_solar - min_solar)

# Reshape scaled solar values for compatibility with the model
solar_normalized = np.expand_dims(solar_scaled, axis=-1)

# Split the data into training, validation, and test sets
x_train, x_test, y_train, y_test = train_test_split(x_data_dsm, solar_normalized, test_size=0.20, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.20, random_state=42)

# Print the shapes of the datasets
print('x_train:', x_train.shape)
print('y_train:', y_train.shape)
print('x_val shape:', x_val.shape)
print('y_val shape:', y_val.shape)
print('x_test shape:', x_test.shape)
print('y_test shape:', y_test.shape)

input_shape = x_train.shape[1:]
# Out:
# Loading Patches: 100%|█████████▉| 7565/7566 [00:41<00:00, 181.36it/s]
# x_train: (4841, 128, 128, 1)
# y_train: (4841, 128, 128, 1)
# x_val shape: (1211, 128, 128, 1)
# y_val shape: (1211, 128, 128, 1)
# x_test shape: (1514, 128, 128, 1)
# y_test shape: (1514, 128, 128, 1)

# %%
print(np.max(solar_values))
print(np.min(solar_values))
print(np.max(dsm_image))
print(np.min(dsm_image))
print(np.max(dsm_image_normalized))
print(np.min(dsm_image_normalized))
# Out:
# 1045434.44
# 0.0
# 14.243
# -1.211
# 1.0
# 0.0

# %%
# import numpy as np
# from skimage import io
# from sklearn.model_selection import train_test_split
# from tqdm import tqdm

# # Initialize empty lists to store data
# x_data_list = []
# y_data_list = []

# # Load all solar map images without normalization
# solar_maps = [io.imread(os.path.join(solar_map_dir, file)) for file in solar_map_files]

# # Concatenate all solar maps along the batch axis
# solar_maps_concatenated = np.concatenate(solar_maps, axis=0)

# # Compute the minimum and maximum values of the concatenated solar maps
# solar_min = np.min(solar_maps_concatenated)
# solar_max = np.max(solar_maps_concatenated)

# # Print the minimum and maximum values
# print("Min Solar Map Value:", solar_min)
# print("Max Solar Map Value:", solar_max)

# # Loop through each patch with tqdm for progress bars
# for i in tqdm(range(min(desired_num_patches, len(dsm_files))), desc='Loading Patches'):
#     # Get file names for the current index
#     dsm_file = dsm_files[i]
#     solar_map_file = solar_map_files[i]
    
#     # Load images
#     dsm_image = io.imread(os.path.join(dsm_images_dir, dsm_file))
#     solar_map = io.imread(os.path.join(solar_map_dir, solar_map_file))

#     # Normalize the data using min-max scaling for DSM
#     if np.min(dsm_image) != np.max(dsm_image):
#         dsm_image_normalized = (dsm_image - np.min(dsm_image)) / (np.max(dsm_image) - np.min(dsm_image))
#     else:
#         dsm_image_normalized = dsm_image

#     # Normalize the data using min-max scaling for Solar Map
#     if solar_min != solar_max:
#         solar_map_normalized = (solar_map - solar_min) / (solar_max - solar_min)
#     else:
#         solar_map_normalized = solar_map

#     # Ensure the shapes match the specified format
#     dsm_image_normalized = np.expand_dims(dsm_image_normalized, axis=-1)
#     solar_map_normalized = np.expand_dims(solar_map_normalized, axis=-1)

#     x_data_list.append(dsm_image_normalized)
#     y_data_list.append(solar_map_normalized)

#     # Break the loop when desired_num_patches is reached
#     if len(x_data_list) >= desired_num_patches:
#         break

# # Combine all patches into a single array
# x_data = np.stack(x_data_list)
# y_data = np.stack(y_data_list)

# # Split the data into training, validation, and test sets
# x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)
# x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# # Print the shapes of the datasets
# print('x_train:', x_train.shape)
# print('y_train:', y_train.shape)
# print('x_val shape:', x_val.shape)
# print('y_val shape:', y_val.shape)
# print('x_test shape:', x_test.shape)
# print('y_test shape:', y_test.shape)

# input_shape = x_data.shape[1:]
# Out:
# Min Solar Map Value: 0.0
# Max Solar Map Value: 1049290.1
# Loading Patches: 100%|█████████▉| 4999/5000 [00:04<00:00, 1185.41it/s]
# x_train: (3200, 128, 128, 1)
# y_train: (3200, 128, 128, 1)
# x_val shape: (800, 128, 128, 1)
# y_val shape: (800, 128, 128, 1)
# x_test shape: (1000, 128, 128, 1)
# y_test shape: (1000, 128, 128, 1)

# %%
# Define the U-Net model
inputs = Input(input_shape)

#Contraction path
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
 
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)
 
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
 
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

#Expansive path 
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
 
u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
 
u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
 
u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
 
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-3
    print('Learning rate: ', lr)
    return lr

# %%
lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

# %%
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
learning_rate = 0.0001
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 16  160         ['input_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 16  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  2320        ['dropout[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   4640        ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   9248        ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 64)   36928       ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 128)  147584      ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    295168      ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 8, 8, 256)    0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    590080      ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  131200     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  295040      ['concatenate[0][0]']
#
#  dropout_5 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  147584      ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  32832       ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 64)   73792       ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   36928       ['dropout_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  8224        ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 32)   9248        ['dropout_7[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  2064       ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 128, 128, 16  0           ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 16  2320        ['dropout_8[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  17          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1,940,817
# Trainable params: 1,940,817
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Modelcheckpoint
checkpointer = tf.keras.callbacks.ModelCheckpoint('Solar_UNET.h5', verbose=1, save_best_only=True)

callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=300, monitor='val_mae'),
        tf.keras.callbacks.TensorBoard(log_dir='logs'),
        checkpointer]
start_time = time.time()
results = model.fit(x_train, y_train, validation_data=(x_val, y_val), batch_size=32, epochs=300 ,
callbacks= callbacks)
end_time = time.time()
training_time_seconds = end_time - start_time
training_time_minutes = training_time_seconds / 60

print("Training completed in {:.2f} seconds ({:.2f} minutes)".format(training_time_seconds, training_time_minutes))
# Out:
# Epoch 1/300
# 152/152 [==============================] - ETA: 0s - loss: 0.0532 - mae: 0.1748
# Epoch 1: val_loss improved from inf to 0.06725, saving model to Solar_UNET.h5
# 152/152 [==============================] - 7s 41ms/step - loss: 0.0532 - mae: 0.1748 - val_loss: 0.0673 - val_mae: 0.1943
# Epoch 2/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0514 - mae: 0.1693
# Epoch 2: val_loss improved from 0.06725 to 0.06392, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0513 - mae: 0.1692 - val_loss: 0.0639 - val_mae: 0.1866
# Epoch 3/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0497 - mae: 0.1647
# Epoch 3: val_loss did not improve from 0.06392
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0497 - mae: 0.1648 - val_loss: 0.0644 - val_mae: 0.1821
# Epoch 4/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0482 - mae: 0.1613
# Epoch 4: val_loss improved from 0.06392 to 0.06266, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0482 - mae: 0.1614 - val_loss: 0.0627 - val_mae: 0.1774
# Epoch 5/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0469 - mae: 0.1580
# Epoch 5: val_loss improved from 0.06266 to 0.05885, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0470 - mae: 0.1580 - val_loss: 0.0588 - val_mae: 0.1724
# Epoch 6/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0456 - mae: 0.1548
# Epoch 6: val_loss improved from 0.05885 to 0.05456, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0456 - mae: 0.1547 - val_loss: 0.0546 - val_mae: 0.1652
# Epoch 7/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0443 - mae: 0.1513
# Epoch 7: val_loss did not improve from 0.05456
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0443 - mae: 0.1514 - val_loss: 0.0599 - val_mae: 0.1721
# Epoch 8/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0432 - mae: 0.1491
# Epoch 8: val_loss improved from 0.05456 to 0.05341, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0432 - mae: 0.1491 - val_loss: 0.0534 - val_mae: 0.1610
# Epoch 9/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0426 - mae: 0.1473
# Epoch 9: val_loss improved from 0.05341 to 0.05024, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0426 - mae: 0.1474 - val_loss: 0.0502 - val_mae: 0.1591
# Epoch 10/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0406 - mae: 0.1429
# Epoch 10: val_loss improved from 0.05024 to 0.04906, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0406 - mae: 0.1429 - val_loss: 0.0491 - val_mae: 0.1519
# Epoch 11/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0396 - mae: 0.1405
# Epoch 11: val_loss did not improve from 0.04906
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0396 - mae: 0.1404 - val_loss: 0.0499 - val_mae: 0.1522
# Epoch 12/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0380 - mae: 0.1362
# Epoch 12: val_loss did not improve from 0.04906
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0379 - mae: 0.1362 - val_loss: 0.0521 - val_mae: 0.1585
# Epoch 13/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0379 - mae: 0.1370
# Epoch 13: val_loss did not improve from 0.04906
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0379 - mae: 0.1369 - val_loss: 0.0500 - val_mae: 0.1509
# Epoch 14/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0380 - mae: 0.1360
# Epoch 14: val_loss improved from 0.04906 to 0.04801, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0379 - mae: 0.1360 - val_loss: 0.0480 - val_mae: 0.1439
# Epoch 15/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0368 - mae: 0.1339
# Epoch 15: val_loss improved from 0.04801 to 0.04441, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0368 - mae: 0.1339 - val_loss: 0.0444 - val_mae: 0.1410
# Epoch 16/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0357 - mae: 0.1311
# Epoch 16: val_loss did not improve from 0.04441
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0358 - mae: 0.1311 - val_loss: 0.0455 - val_mae: 0.1448
# Epoch 17/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0349 - mae: 0.1298
# Epoch 17: val_loss improved from 0.04441 to 0.04322, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 35ms/step - loss: 0.0349 - mae: 0.1297 - val_loss: 0.0432 - val_mae: 0.1416
# Epoch 18/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0339 - mae: 0.1275
# Epoch 18: val_loss improved from 0.04322 to 0.04186, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 35ms/step - loss: 0.0339 - mae: 0.1276 - val_loss: 0.0419 - val_mae: 0.1352
# Epoch 19/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0328 - mae: 0.1247
# Epoch 19: val_loss did not improve from 0.04186
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0328 - mae: 0.1247 - val_loss: 0.0433 - val_mae: 0.1394
# Epoch 20/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0330 - mae: 0.1254
# Epoch 20: val_loss did not improve from 0.04186
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0330 - mae: 0.1254 - val_loss: 0.0478 - val_mae: 0.1436
# Epoch 21/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0318 - mae: 0.1224
# Epoch 21: val_loss did not improve from 0.04186
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0318 - mae: 0.1225 - val_loss: 0.0486 - val_mae: 0.1447
# Epoch 22/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0313 - mae: 0.1216
# Epoch 22: val_loss did not improve from 0.04186
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0313 - mae: 0.1216 - val_loss: 0.0444 - val_mae: 0.1395
# Epoch 23/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0298 - mae: 0.1179
# Epoch 23: val_loss did not improve from 0.04186
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0298 - mae: 0.1179 - val_loss: 0.0457 - val_mae: 0.1392
# Epoch 24/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0293 - mae: 0.1170
# Epoch 24: val_loss did not improve from 0.04186
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0293 - mae: 0.1170 - val_loss: 0.0427 - val_mae: 0.1343
# Epoch 25/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0304 - mae: 0.1196
# Epoch 25: val_loss improved from 0.04186 to 0.04012, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0304 - mae: 0.1196 - val_loss: 0.0401 - val_mae: 0.1295
# Epoch 26/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0282 - mae: 0.1145
# Epoch 26: val_loss did not improve from 0.04012
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0282 - mae: 0.1144 - val_loss: 0.0413 - val_mae: 0.1318
# Epoch 27/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0280 - mae: 0.1137
# Epoch 27: val_loss did not improve from 0.04012
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0280 - mae: 0.1137 - val_loss: 0.0405 - val_mae: 0.1296
# Epoch 28/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0273 - mae: 0.1123
# Epoch 28: val_loss did not improve from 0.04012
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0273 - mae: 0.1123 - val_loss: 0.0442 - val_mae: 0.1351
# Epoch 29/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0267 - mae: 0.1107
# Epoch 29: val_loss did not improve from 0.04012
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0267 - mae: 0.1107 - val_loss: 0.0442 - val_mae: 0.1330
# Epoch 30/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0261 - mae: 0.1095
# Epoch 30: val_loss did not improve from 0.04012
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0261 - mae: 0.1095 - val_loss: 0.0448 - val_mae: 0.1342
# Epoch 31/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0249 - mae: 0.1063
# Epoch 31: val_loss did not improve from 0.04012
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0249 - mae: 0.1063 - val_loss: 0.0417 - val_mae: 0.1298
# Epoch 32/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0247 - mae: 0.1061
# Epoch 32: val_loss improved from 0.04012 to 0.03990, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0247 - mae: 0.1061 - val_loss: 0.0399 - val_mae: 0.1248
# Epoch 33/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0248 - mae: 0.1060
# Epoch 33: val_loss did not improve from 0.03990
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0248 - mae: 0.1060 - val_loss: 0.0429 - val_mae: 0.1287
# Epoch 34/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0262 - mae: 0.1089
# Epoch 34: val_loss did not improve from 0.03990
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0262 - mae: 0.1090 - val_loss: 0.0402 - val_mae: 0.1282
# Epoch 35/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0241 - mae: 0.1050
# Epoch 35: val_loss improved from 0.03990 to 0.03938, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0241 - mae: 0.1050 - val_loss: 0.0394 - val_mae: 0.1243
# Epoch 36/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0235 - mae: 0.1031
# Epoch 36: val_loss improved from 0.03938 to 0.03921, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0235 - mae: 0.1031 - val_loss: 0.0392 - val_mae: 0.1236
# Epoch 37/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0247 - mae: 0.1057
# Epoch 37: val_loss did not improve from 0.03921
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0246 - mae: 0.1057 - val_loss: 0.0464 - val_mae: 0.1335
# Epoch 38/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0243 - mae: 0.1050
# Epoch 38: val_loss did not improve from 0.03921
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0243 - mae: 0.1050 - val_loss: 0.0435 - val_mae: 0.1276
# Epoch 39/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0226 - mae: 0.1008
# Epoch 39: val_loss did not improve from 0.03921
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0226 - mae: 0.1008 - val_loss: 0.0423 - val_mae: 0.1252
# Epoch 40/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0224 - mae: 0.0998
# Epoch 40: val_loss improved from 0.03921 to 0.03717, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0224 - mae: 0.0998 - val_loss: 0.0372 - val_mae: 0.1206
# Epoch 41/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0221 - mae: 0.0997
# Epoch 41: val_loss improved from 0.03717 to 0.03667, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0221 - mae: 0.0997 - val_loss: 0.0367 - val_mae: 0.1193
# Epoch 42/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0209 - mae: 0.0968
# Epoch 42: val_loss did not improve from 0.03667
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0209 - mae: 0.0968 - val_loss: 0.0376 - val_mae: 0.1190
# Epoch 43/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0206 - mae: 0.0959
# Epoch 43: val_loss did not improve from 0.03667
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0206 - mae: 0.0959 - val_loss: 0.0388 - val_mae: 0.1188
# Epoch 44/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0204 - mae: 0.0954
# Epoch 44: val_loss did not improve from 0.03667
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0204 - mae: 0.0954 - val_loss: 0.0380 - val_mae: 0.1187
# Epoch 45/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0227 - mae: 0.0996
# Epoch 45: val_loss did not improve from 0.03667
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0227 - mae: 0.0997 - val_loss: 0.0368 - val_mae: 0.1217
# Epoch 46/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0209 - mae: 0.0971
# Epoch 46: val_loss did not improve from 0.03667
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0209 - mae: 0.0971 - val_loss: 0.0383 - val_mae: 0.1180
# Epoch 47/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0197 - mae: 0.0936
# Epoch 47: val_loss did not improve from 0.03667
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0196 - mae: 0.0936 - val_loss: 0.0401 - val_mae: 0.1224
# Epoch 48/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0192 - mae: 0.0925
# Epoch 48: val_loss improved from 0.03667 to 0.03557, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0192 - mae: 0.0925 - val_loss: 0.0356 - val_mae: 0.1144
# Epoch 49/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0194 - mae: 0.0925
# Epoch 49: val_loss did not improve from 0.03557
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0194 - mae: 0.0925 - val_loss: 0.0365 - val_mae: 0.1149
# Epoch 50/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0189 - mae: 0.0918
# Epoch 50: val_loss improved from 0.03557 to 0.03496, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 35ms/step - loss: 0.0189 - mae: 0.0918 - val_loss: 0.0350 - val_mae: 0.1114
# Epoch 51/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0183 - mae: 0.0901
# Epoch 51: val_loss did not improve from 0.03496
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0183 - mae: 0.0901 - val_loss: 0.0370 - val_mae: 0.1139
# Epoch 52/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0197 - mae: 0.0932
# Epoch 52: val_loss did not improve from 0.03496
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0198 - mae: 0.0932 - val_loss: 0.0386 - val_mae: 0.1180
# Epoch 53/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0201 - mae: 0.0945
# Epoch 53: val_loss did not improve from 0.03496
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0201 - mae: 0.0945 - val_loss: 0.0363 - val_mae: 0.1138
# Epoch 54/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0183 - mae: 0.0898
# Epoch 54: val_loss improved from 0.03496 to 0.03082, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0183 - mae: 0.0898 - val_loss: 0.0308 - val_mae: 0.1059
# Epoch 55/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0193 - mae: 0.0924
# Epoch 55: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0193 - mae: 0.0923 - val_loss: 0.0334 - val_mae: 0.1093
# Epoch 56/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0177 - mae: 0.0885
# Epoch 56: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0176 - mae: 0.0885 - val_loss: 0.0338 - val_mae: 0.1090
# Epoch 57/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0179 - mae: 0.0889
# Epoch 57: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0179 - mae: 0.0889 - val_loss: 0.0329 - val_mae: 0.1078
# Epoch 58/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0171 - mae: 0.0871
# Epoch 58: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0171 - mae: 0.0871 - val_loss: 0.0342 - val_mae: 0.1096
# Epoch 59/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0170 - mae: 0.0866
# Epoch 59: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0170 - mae: 0.0866 - val_loss: 0.0335 - val_mae: 0.1067
# Epoch 60/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0170 - mae: 0.0864
# Epoch 60: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0170 - mae: 0.0864 - val_loss: 0.0346 - val_mae: 0.1080
# Epoch 61/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0170 - mae: 0.0866
# Epoch 61: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0170 - mae: 0.0866 - val_loss: 0.0326 - val_mae: 0.1071
# Epoch 62/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0170 - mae: 0.0864
# Epoch 62: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0170 - mae: 0.0864 - val_loss: 0.0335 - val_mae: 0.1072
# Epoch 63/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0173 - mae: 0.0875
# Epoch 63: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0173 - mae: 0.0875 - val_loss: 0.0318 - val_mae: 0.1055
# Epoch 64/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0174 - mae: 0.0874
# Epoch 64: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0174 - mae: 0.0874 - val_loss: 0.0357 - val_mae: 0.1119
# Epoch 65/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0167 - mae: 0.0857
# Epoch 65: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0167 - mae: 0.0857 - val_loss: 0.0332 - val_mae: 0.1075
# Epoch 66/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0172 - mae: 0.0867
# Epoch 66: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0172 - mae: 0.0867 - val_loss: 0.0348 - val_mae: 0.1090
# Epoch 67/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0157 - mae: 0.0833
# Epoch 67: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0158 - mae: 0.0833 - val_loss: 0.0320 - val_mae: 0.1039
# Epoch 68/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0155 - mae: 0.0827
# Epoch 68: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0155 - mae: 0.0827 - val_loss: 0.0310 - val_mae: 0.1025
# Epoch 69/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0164 - mae: 0.0842
# Epoch 69: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0164 - mae: 0.0843 - val_loss: 0.0353 - val_mae: 0.1133
# Epoch 70/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0176 - mae: 0.0879
# Epoch 70: val_loss did not improve from 0.03082
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0177 - mae: 0.0879 - val_loss: 0.0344 - val_mae: 0.1077
# Epoch 71/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0156 - mae: 0.0826
# Epoch 71: val_loss improved from 0.03082 to 0.02949, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0156 - mae: 0.0826 - val_loss: 0.0295 - val_mae: 0.1008
# Epoch 72/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0149 - mae: 0.0809
# Epoch 72: val_loss improved from 0.02949 to 0.02939, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0149 - mae: 0.0809 - val_loss: 0.0294 - val_mae: 0.0995
# Epoch 73/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0148 - mae: 0.0806
# Epoch 73: val_loss did not improve from 0.02939
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0148 - mae: 0.0806 - val_loss: 0.0305 - val_mae: 0.1011
# Epoch 74/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0148 - mae: 0.0804
# Epoch 74: val_loss did not improve from 0.02939
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0148 - mae: 0.0804 - val_loss: 0.0303 - val_mae: 0.1004
# Epoch 75/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0164 - mae: 0.0838
# Epoch 75: val_loss did not improve from 0.02939
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0164 - mae: 0.0839 - val_loss: 0.0322 - val_mae: 0.1045
# Epoch 76/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0152 - mae: 0.0814
# Epoch 76: val_loss did not improve from 0.02939
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0152 - mae: 0.0815 - val_loss: 0.0333 - val_mae: 0.1047
# Epoch 77/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0145 - mae: 0.0796
# Epoch 77: val_loss did not improve from 0.02939
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0145 - mae: 0.0796 - val_loss: 0.0308 - val_mae: 0.1008
# Epoch 78/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0143 - mae: 0.0791
# Epoch 78: val_loss did not improve from 0.02939
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0143 - mae: 0.0791 - val_loss: 0.0301 - val_mae: 0.0992
# Epoch 79/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0142 - mae: 0.0786
# Epoch 79: val_loss did not improve from 0.02939
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0142 - mae: 0.0786 - val_loss: 0.0302 - val_mae: 0.0990
# Epoch 80/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0143 - mae: 0.0790
# Epoch 80: val_loss improved from 0.02939 to 0.02706, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0143 - mae: 0.0790 - val_loss: 0.0271 - val_mae: 0.0951
# Epoch 81/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0145 - mae: 0.0793
# Epoch 81: val_loss did not improve from 0.02706
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0145 - mae: 0.0793 - val_loss: 0.0309 - val_mae: 0.1018
# Epoch 82/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0151 - mae: 0.0807
# Epoch 82: val_loss did not improve from 0.02706
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0151 - mae: 0.0807 - val_loss: 0.0273 - val_mae: 0.0961
# Epoch 83/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0143 - mae: 0.0787
# Epoch 83: val_loss did not improve from 0.02706
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0143 - mae: 0.0787 - val_loss: 0.0280 - val_mae: 0.0968
# Epoch 84/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0137 - mae: 0.0773
# Epoch 84: val_loss did not improve from 0.02706
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0137 - mae: 0.0773 - val_loss: 0.0300 - val_mae: 0.0983
# Epoch 85/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0135 - mae: 0.0767
# Epoch 85: val_loss did not improve from 0.02706
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0135 - mae: 0.0767 - val_loss: 0.0274 - val_mae: 0.0950
# Epoch 86/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0135 - mae: 0.0764
# Epoch 86: val_loss did not improve from 0.02706
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0135 - mae: 0.0764 - val_loss: 0.0300 - val_mae: 0.0973
# Epoch 87/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0151 - mae: 0.0797
# Epoch 87: val_loss did not improve from 0.02706
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0151 - mae: 0.0797 - val_loss: 0.0291 - val_mae: 0.1018
# Epoch 88/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0157 - mae: 0.0822
# Epoch 88: val_loss did not improve from 0.02706
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0157 - mae: 0.0822 - val_loss: 0.0287 - val_mae: 0.0966
# Epoch 89/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0134 - mae: 0.0765
# Epoch 89: val_loss did not improve from 0.02706
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0134 - mae: 0.0765 - val_loss: 0.0278 - val_mae: 0.0954
# Epoch 90/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0131 - mae: 0.0754
# Epoch 90: val_loss improved from 0.02706 to 0.02661, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0131 - mae: 0.0754 - val_loss: 0.0266 - val_mae: 0.0929
# Epoch 91/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0131 - mae: 0.0752
# Epoch 91: val_loss did not improve from 0.02661
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0131 - mae: 0.0752 - val_loss: 0.0279 - val_mae: 0.0968
# Epoch 92/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0137 - mae: 0.0767
# Epoch 92: val_loss did not improve from 0.02661
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0137 - mae: 0.0767 - val_loss: 0.0284 - val_mae: 0.0976
# Epoch 93/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0174 - mae: 0.0857
# Epoch 93: val_loss improved from 0.02661 to 0.02620, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 35ms/step - loss: 0.0173 - mae: 0.0856 - val_loss: 0.0262 - val_mae: 0.0923
# Epoch 94/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0131 - mae: 0.0753
# Epoch 94: val_loss did not improve from 0.02620
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0131 - mae: 0.0753 - val_loss: 0.0277 - val_mae: 0.0945
# Epoch 95/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0128 - mae: 0.0743
# Epoch 95: val_loss did not improve from 0.02620
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0127 - mae: 0.0743 - val_loss: 0.0266 - val_mae: 0.0922
# Epoch 96/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0128 - mae: 0.0742
# Epoch 96: val_loss did not improve from 0.02620
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0128 - mae: 0.0743 - val_loss: 0.0266 - val_mae: 0.0924
# Epoch 97/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0125 - mae: 0.0735
# Epoch 97: val_loss improved from 0.02620 to 0.02617, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0125 - mae: 0.0735 - val_loss: 0.0262 - val_mae: 0.0913
# Epoch 98/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0124 - mae: 0.0731
# Epoch 98: val_loss improved from 0.02617 to 0.02558, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 35ms/step - loss: 0.0124 - mae: 0.0732 - val_loss: 0.0256 - val_mae: 0.0908
# Epoch 99/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0126 - mae: 0.0735
# Epoch 99: val_loss did not improve from 0.02558
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0126 - mae: 0.0735 - val_loss: 0.0268 - val_mae: 0.0916
# Epoch 100/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0123 - mae: 0.0728
# Epoch 100: val_loss did not improve from 0.02558
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0123 - mae: 0.0728 - val_loss: 0.0262 - val_mae: 0.0907
# Epoch 101/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0121 - mae: 0.0722
# Epoch 101: val_loss did not improve from 0.02558
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0121 - mae: 0.0722 - val_loss: 0.0275 - val_mae: 0.0924
# Epoch 102/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0122 - mae: 0.0724
# Epoch 102: val_loss did not improve from 0.02558
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0122 - mae: 0.0724 - val_loss: 0.0286 - val_mae: 0.0948
# Epoch 103/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0121 - mae: 0.0722
# Epoch 103: val_loss did not improve from 0.02558
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0121 - mae: 0.0722 - val_loss: 0.0258 - val_mae: 0.0902
# Epoch 104/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0120 - mae: 0.0717
# Epoch 104: val_loss did not improve from 0.02558
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0120 - mae: 0.0717 - val_loss: 0.0258 - val_mae: 0.0908
# Epoch 105/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0121 - mae: 0.0719
# Epoch 105: val_loss improved from 0.02558 to 0.02549, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 35ms/step - loss: 0.0121 - mae: 0.0719 - val_loss: 0.0255 - val_mae: 0.0896
# Epoch 106/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0126 - mae: 0.0729
# Epoch 106: val_loss did not improve from 0.02549
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0126 - mae: 0.0730 - val_loss: 0.0330 - val_mae: 0.1068
# Epoch 107/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0143 - mae: 0.0776
# Epoch 107: val_loss improved from 0.02549 to 0.02529, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 35ms/step - loss: 0.0143 - mae: 0.0776 - val_loss: 0.0253 - val_mae: 0.0903
# Epoch 108/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0119 - mae: 0.0713
# Epoch 108: val_loss improved from 0.02529 to 0.02451, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0119 - mae: 0.0713 - val_loss: 0.0245 - val_mae: 0.0882
# Epoch 109/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0116 - mae: 0.0705
# Epoch 109: val_loss did not improve from 0.02451
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0116 - mae: 0.0705 - val_loss: 0.0249 - val_mae: 0.0881
# Epoch 110/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0115 - mae: 0.0703
# Epoch 110: val_loss did not improve from 0.02451
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0115 - mae: 0.0703 - val_loss: 0.0253 - val_mae: 0.0890
# Epoch 111/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0114 - mae: 0.0698
# Epoch 111: val_loss did not improve from 0.02451
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0114 - mae: 0.0698 - val_loss: 0.0249 - val_mae: 0.0888
# Epoch 112/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0114 - mae: 0.0698
# Epoch 112: val_loss improved from 0.02451 to 0.02417, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 35ms/step - loss: 0.0114 - mae: 0.0698 - val_loss: 0.0242 - val_mae: 0.0872
# Epoch 113/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0113 - mae: 0.0693
# Epoch 113: val_loss improved from 0.02417 to 0.02378, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0113 - mae: 0.0693 - val_loss: 0.0238 - val_mae: 0.0867
# Epoch 114/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0112 - mae: 0.0692
# Epoch 114: val_loss improved from 0.02378 to 0.02353, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0112 - mae: 0.0692 - val_loss: 0.0235 - val_mae: 0.0861
# Epoch 115/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0112 - mae: 0.0691
# Epoch 115: val_loss did not improve from 0.02353
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0112 - mae: 0.0691 - val_loss: 0.0249 - val_mae: 0.0875
# Epoch 116/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0124 - mae: 0.0716
# Epoch 116: val_loss did not improve from 0.02353
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0124 - mae: 0.0716 - val_loss: 0.0276 - val_mae: 0.0935
# Epoch 117/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0121 - mae: 0.0717
# Epoch 117: val_loss did not improve from 0.02353
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0121 - mae: 0.0717 - val_loss: 0.0265 - val_mae: 0.0902
# Epoch 118/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0111 - mae: 0.0688
# Epoch 118: val_loss improved from 0.02353 to 0.02344, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0111 - mae: 0.0688 - val_loss: 0.0234 - val_mae: 0.0857
# Epoch 119/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0109 - mae: 0.0679
# Epoch 119: val_loss did not improve from 0.02344
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0109 - mae: 0.0679 - val_loss: 0.0246 - val_mae: 0.0872
# Epoch 120/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0110 - mae: 0.0683
# Epoch 120: val_loss improved from 0.02344 to 0.02230, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0110 - mae: 0.0683 - val_loss: 0.0223 - val_mae: 0.0838
# Epoch 121/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0113 - mae: 0.0691
# Epoch 121: val_loss did not improve from 0.02230
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0113 - mae: 0.0691 - val_loss: 0.0265 - val_mae: 0.0906
# Epoch 122/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0107 - mae: 0.0676
# Epoch 122: val_loss did not improve from 0.02230
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0107 - mae: 0.0676 - val_loss: 0.0237 - val_mae: 0.0867
# Epoch 123/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0106 - mae: 0.0669
# Epoch 123: val_loss did not improve from 0.02230
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0106 - mae: 0.0669 - val_loss: 0.0243 - val_mae: 0.0867
# Epoch 124/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0105 - mae: 0.0665
# Epoch 124: val_loss did not improve from 0.02230
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0105 - mae: 0.0665 - val_loss: 0.0236 - val_mae: 0.0860
# Epoch 125/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0110 - mae: 0.0680
# Epoch 125: val_loss did not improve from 0.02230
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0110 - mae: 0.0680 - val_loss: 0.0245 - val_mae: 0.0871
# Epoch 126/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0112 - mae: 0.0683
# Epoch 126: val_loss did not improve from 0.02230
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0112 - mae: 0.0683 - val_loss: 0.0250 - val_mae: 0.0884
# Epoch 127/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0108 - mae: 0.0676
# Epoch 127: val_loss did not improve from 0.02230
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0108 - mae: 0.0676 - val_loss: 0.0231 - val_mae: 0.0848
# Epoch 128/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0103 - mae: 0.0660
# Epoch 128: val_loss did not improve from 0.02230
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0103 - mae: 0.0660 - val_loss: 0.0252 - val_mae: 0.0873
# Epoch 129/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0131 - mae: 0.0730
# Epoch 129: val_loss did not improve from 0.02230
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0131 - mae: 0.0729 - val_loss: 0.0236 - val_mae: 0.0859
# Epoch 130/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0106 - mae: 0.0669
# Epoch 130: val_loss did not improve from 0.02230
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0106 - mae: 0.0669 - val_loss: 0.0228 - val_mae: 0.0842
# Epoch 131/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0103 - mae: 0.0658
# Epoch 131: val_loss did not improve from 0.02230
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0103 - mae: 0.0658 - val_loss: 0.0229 - val_mae: 0.0842
# Epoch 132/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0101 - mae: 0.0652
# Epoch 132: val_loss did not improve from 0.02230
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0101 - mae: 0.0652 - val_loss: 0.0230 - val_mae: 0.0842
# Epoch 133/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0101 - mae: 0.0652
# Epoch 133: val_loss did not improve from 0.02230
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0101 - mae: 0.0652 - val_loss: 0.0237 - val_mae: 0.0857
# Epoch 134/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0100 - mae: 0.0649
# Epoch 134: val_loss improved from 0.02230 to 0.02211, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0100 - mae: 0.0650 - val_loss: 0.0221 - val_mae: 0.0835
# Epoch 135/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0104 - mae: 0.0658
# Epoch 135: val_loss did not improve from 0.02211
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0104 - mae: 0.0658 - val_loss: 0.0337 - val_mae: 0.1024
# Epoch 136/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0127 - mae: 0.0717
# Epoch 136: val_loss did not improve from 0.02211
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0127 - mae: 0.0717 - val_loss: 0.0247 - val_mae: 0.0897
# Epoch 137/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0106 - mae: 0.0666
# Epoch 137: val_loss did not improve from 0.02211
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0106 - mae: 0.0666 - val_loss: 0.0233 - val_mae: 0.0846
# Epoch 138/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0103 - mae: 0.0657
# Epoch 138: val_loss did not improve from 0.02211
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0103 - mae: 0.0656 - val_loss: 0.0267 - val_mae: 0.0895
# Epoch 139/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0101 - mae: 0.0650
# Epoch 139: val_loss did not improve from 0.02211
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0101 - mae: 0.0650 - val_loss: 0.0222 - val_mae: 0.0830
# Epoch 140/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0099 - mae: 0.0644
# Epoch 140: val_loss improved from 0.02211 to 0.02204, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0099 - mae: 0.0644 - val_loss: 0.0220 - val_mae: 0.0836
# Epoch 141/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0097 - mae: 0.0637
# Epoch 141: val_loss did not improve from 0.02204
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0097 - mae: 0.0637 - val_loss: 0.0224 - val_mae: 0.0832
# Epoch 142/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0096 - mae: 0.0634
# Epoch 142: val_loss improved from 0.02204 to 0.02145, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0096 - mae: 0.0635 - val_loss: 0.0214 - val_mae: 0.0820
# Epoch 143/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0096 - mae: 0.0634
# Epoch 143: val_loss did not improve from 0.02145
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0096 - mae: 0.0634 - val_loss: 0.0215 - val_mae: 0.0820
# Epoch 144/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0095 - mae: 0.0631
# Epoch 144: val_loss improved from 0.02145 to 0.02080, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0095 - mae: 0.0631 - val_loss: 0.0208 - val_mae: 0.0806
# Epoch 145/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0095 - mae: 0.0631
# Epoch 145: val_loss did not improve from 0.02080
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0095 - mae: 0.0631 - val_loss: 0.0225 - val_mae: 0.0832
# Epoch 146/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0096 - mae: 0.0632
# Epoch 146: val_loss did not improve from 0.02080
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0096 - mae: 0.0632 - val_loss: 0.0225 - val_mae: 0.0826
# Epoch 147/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0096 - mae: 0.0633
# Epoch 147: val_loss did not improve from 0.02080
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0096 - mae: 0.0633 - val_loss: 0.0222 - val_mae: 0.0825
# Epoch 148/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0095 - mae: 0.0629
# Epoch 148: val_loss did not improve from 0.02080
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0095 - mae: 0.0629 - val_loss: 0.0216 - val_mae: 0.0813
# Epoch 149/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0093 - mae: 0.0625
# Epoch 149: val_loss did not improve from 0.02080
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0093 - mae: 0.0625 - val_loss: 0.0216 - val_mae: 0.0811
# Epoch 150/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0095 - mae: 0.0629
# Epoch 150: val_loss did not improve from 0.02080
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0095 - mae: 0.0629 - val_loss: 0.0218 - val_mae: 0.0812
# Epoch 151/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0093 - mae: 0.0622
# Epoch 151: val_loss did not improve from 0.02080
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0093 - mae: 0.0623 - val_loss: 0.0213 - val_mae: 0.0815
# Epoch 152/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0091 - mae: 0.0618
# Epoch 152: val_loss did not improve from 0.02080
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0091 - mae: 0.0618 - val_loss: 0.0218 - val_mae: 0.0811
# Epoch 153/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0092 - mae: 0.0620
# Epoch 153: val_loss improved from 0.02080 to 0.01957, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0092 - mae: 0.0619 - val_loss: 0.0196 - val_mae: 0.0788
# Epoch 154/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0091 - mae: 0.0616
# Epoch 154: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0091 - mae: 0.0616 - val_loss: 0.0245 - val_mae: 0.0852
# Epoch 155/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0099 - mae: 0.0637
# Epoch 155: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0099 - mae: 0.0637 - val_loss: 0.0241 - val_mae: 0.0869
# Epoch 156/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0103 - mae: 0.0650
# Epoch 156: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0103 - mae: 0.0650 - val_loss: 0.0232 - val_mae: 0.0836
# Epoch 157/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0091 - mae: 0.0616
# Epoch 157: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0091 - mae: 0.0616 - val_loss: 0.0228 - val_mae: 0.0826
# Epoch 158/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0089 - mae: 0.0609
# Epoch 158: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0089 - mae: 0.0610 - val_loss: 0.0210 - val_mae: 0.0802
# Epoch 159/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0089 - mae: 0.0607
# Epoch 159: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0089 - mae: 0.0606 - val_loss: 0.0204 - val_mae: 0.0790
# Epoch 160/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0088 - mae: 0.0604
# Epoch 160: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0088 - mae: 0.0604 - val_loss: 0.0230 - val_mae: 0.0827
# Epoch 161/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0088 - mae: 0.0604
# Epoch 161: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0088 - mae: 0.0604 - val_loss: 0.0218 - val_mae: 0.0805
# Epoch 162/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0088 - mae: 0.0603
# Epoch 162: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0088 - mae: 0.0603 - val_loss: 0.0211 - val_mae: 0.0803
# Epoch 163/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0088 - mae: 0.0603
# Epoch 163: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0088 - mae: 0.0603 - val_loss: 0.0211 - val_mae: 0.0803
# Epoch 164/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0133 - mae: 0.0724
# Epoch 164: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0133 - mae: 0.0724 - val_loss: 0.0221 - val_mae: 0.0842
# Epoch 165/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0116 - mae: 0.0682
# Epoch 165: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0116 - mae: 0.0682 - val_loss: 0.0242 - val_mae: 0.0860
# Epoch 166/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0092 - mae: 0.0619
# Epoch 166: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0092 - mae: 0.0619 - val_loss: 0.0204 - val_mae: 0.0799
# Epoch 167/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0088 - mae: 0.0603
# Epoch 167: val_loss did not improve from 0.01957
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0088 - mae: 0.0603 - val_loss: 0.0197 - val_mae: 0.0783
# Epoch 168/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0087 - mae: 0.0599
# Epoch 168: val_loss improved from 0.01957 to 0.01950, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0087 - mae: 0.0599 - val_loss: 0.0195 - val_mae: 0.0780
# Epoch 169/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0086 - mae: 0.0595
# Epoch 169: val_loss improved from 0.01950 to 0.01916, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0086 - mae: 0.0595 - val_loss: 0.0192 - val_mae: 0.0776
# Epoch 170/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0085 - mae: 0.0593
# Epoch 170: val_loss did not improve from 0.01916
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0085 - mae: 0.0593 - val_loss: 0.0193 - val_mae: 0.0774
# Epoch 171/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0085 - mae: 0.0592
# Epoch 171: val_loss did not improve from 0.01916
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0085 - mae: 0.0592 - val_loss: 0.0195 - val_mae: 0.0778
# Epoch 172/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0084 - mae: 0.0589
# Epoch 172: val_loss improved from 0.01916 to 0.01898, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0084 - mae: 0.0589 - val_loss: 0.0190 - val_mae: 0.0766
# Epoch 173/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0084 - mae: 0.0590
# Epoch 173: val_loss did not improve from 0.01898
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0084 - mae: 0.0590 - val_loss: 0.0190 - val_mae: 0.0776
# Epoch 174/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0084 - mae: 0.0589
# Epoch 174: val_loss did not improve from 0.01898
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0084 - mae: 0.0588 - val_loss: 0.0191 - val_mae: 0.0768
# Epoch 175/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0083 - mae: 0.0586
# Epoch 175: val_loss improved from 0.01898 to 0.01864, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0083 - mae: 0.0586 - val_loss: 0.0186 - val_mae: 0.0762
# Epoch 176/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0083 - mae: 0.0585
# Epoch 176: val_loss improved from 0.01864 to 0.01855, saving model to Solar_UNET.h5
# ...
# Epoch 242/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0068 - mae: 0.0522
# Epoch 242: val_loss did not improve from 0.01627
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0068 - mae: 0.0521 - val_loss: 0.0170 - val_mae: 0.0707
# Epoch 243/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0068 - mae: 0.0521
# Epoch 243: val_loss did not improve from 0.01627
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0068 - mae: 0.0521 - val_loss: 0.0163 - val_mae: 0.0703
# Epoch 244/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0068 - mae: 0.0521
# Epoch 244: val_loss did not improve from 0.01627
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0068 - mae: 0.0521 - val_loss: 0.0172 - val_mae: 0.0714
# Epoch 245/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0067 - mae: 0.0519
# Epoch 245: val_loss did not improve from 0.01627
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0067 - mae: 0.0519 - val_loss: 0.0174 - val_mae: 0.0712
# Epoch 246/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0067 - mae: 0.0518
# Epoch 246: val_loss improved from 0.01627 to 0.01624, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 35ms/step - loss: 0.0067 - mae: 0.0518 - val_loss: 0.0162 - val_mae: 0.0705
# Epoch 247/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0084 - mae: 0.0562
# Epoch 247: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0084 - mae: 0.0563 - val_loss: 0.0213 - val_mae: 0.0842
# Epoch 248/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0084 - mae: 0.0573
# Epoch 248: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0084 - mae: 0.0573 - val_loss: 0.0216 - val_mae: 0.0831
# Epoch 249/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0072 - mae: 0.0537
# Epoch 249: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0072 - mae: 0.0537 - val_loss: 0.0184 - val_mae: 0.0737
# Epoch 250/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0068 - mae: 0.0520
# Epoch 250: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0068 - mae: 0.0520 - val_loss: 0.0187 - val_mae: 0.0734
# Epoch 251/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0068 - mae: 0.0521
# Epoch 251: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0068 - mae: 0.0521 - val_loss: 0.0193 - val_mae: 0.0752
# Epoch 252/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0069 - mae: 0.0524
# Epoch 252: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0069 - mae: 0.0524 - val_loss: 0.0181 - val_mae: 0.0724
# Epoch 253/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0067 - mae: 0.0517
# Epoch 253: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0067 - mae: 0.0517 - val_loss: 0.0184 - val_mae: 0.0727
# Epoch 254/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0067 - mae: 0.0515
# Epoch 254: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0067 - mae: 0.0515 - val_loss: 0.0179 - val_mae: 0.0716
# Epoch 255/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0066 - mae: 0.0512
# Epoch 255: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0066 - mae: 0.0512 - val_loss: 0.0174 - val_mae: 0.0712
# Epoch 256/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0066 - mae: 0.0512
# Epoch 256: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0066 - mae: 0.0512 - val_loss: 0.0176 - val_mae: 0.0713
# Epoch 257/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0066 - mae: 0.0511
# Epoch 257: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0066 - mae: 0.0511 - val_loss: 0.0173 - val_mae: 0.0723
# Epoch 258/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0066 - mae: 0.0511
# Epoch 258: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0066 - mae: 0.0511 - val_loss: 0.0174 - val_mae: 0.0708
# Epoch 259/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0067 - mae: 0.0517
# Epoch 259: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0067 - mae: 0.0517 - val_loss: 0.0188 - val_mae: 0.0732
# Epoch 260/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0069 - mae: 0.0519
# Epoch 260: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0069 - mae: 0.0519 - val_loss: 0.0254 - val_mae: 0.0851
# Epoch 261/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0084 - mae: 0.0572
# Epoch 261: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0084 - mae: 0.0572 - val_loss: 0.0175 - val_mae: 0.0717
# Epoch 262/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0066 - mae: 0.0515
# Epoch 262: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0066 - mae: 0.0515 - val_loss: 0.0176 - val_mae: 0.0713
# Epoch 263/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0066 - mae: 0.0510
# Epoch 263: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0066 - mae: 0.0510 - val_loss: 0.0169 - val_mae: 0.0707
# Epoch 264/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0065 - mae: 0.0508
# Epoch 264: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0065 - mae: 0.0508 - val_loss: 0.0178 - val_mae: 0.0714
# Epoch 265/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0065 - mae: 0.0508
# Epoch 265: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0065 - mae: 0.0509 - val_loss: 0.0172 - val_mae: 0.0708
# Epoch 266/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0506
# Epoch 266: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0064 - mae: 0.0506 - val_loss: 0.0167 - val_mae: 0.0699
# Epoch 267/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0505
# Epoch 267: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0064 - mae: 0.0505 - val_loss: 0.0167 - val_mae: 0.0703
# Epoch 268/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0503
# Epoch 268: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0064 - mae: 0.0503 - val_loss: 0.0169 - val_mae: 0.0703
# Epoch 269/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0503
# Epoch 269: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0064 - mae: 0.0503 - val_loss: 0.0181 - val_mae: 0.0718
# Epoch 270/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0503
# Epoch 270: val_loss did not improve from 0.01624
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0064 - mae: 0.0503 - val_loss: 0.0167 - val_mae: 0.0696
# Epoch 271/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0501
# Epoch 271: val_loss improved from 0.01624 to 0.01598, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0063 - mae: 0.0501 - val_loss: 0.0160 - val_mae: 0.0683
# Epoch 272/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0501
# Epoch 272: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0063 - mae: 0.0501 - val_loss: 0.0160 - val_mae: 0.0683
# Epoch 273/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0504
# Epoch 273: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 33ms/step - loss: 0.0064 - mae: 0.0504 - val_loss: 0.0163 - val_mae: 0.0688
# Epoch 274/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0102 - mae: 0.0612
# Epoch 274: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0102 - mae: 0.0612 - val_loss: 0.0229 - val_mae: 0.0819
# Epoch 275/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0083 - mae: 0.0569
# Epoch 275: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0083 - mae: 0.0569 - val_loss: 0.0181 - val_mae: 0.0730
# Epoch 276/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0068 - mae: 0.0521
# Epoch 276: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0068 - mae: 0.0521 - val_loss: 0.0194 - val_mae: 0.0745
# Epoch 277/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0066 - mae: 0.0511
# Epoch 277: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0066 - mae: 0.0511 - val_loss: 0.0176 - val_mae: 0.0719
# Epoch 278/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0505
# Epoch 278: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0064 - mae: 0.0505 - val_loss: 0.0176 - val_mae: 0.0710
# Epoch 279/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0503
# Epoch 279: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0064 - mae: 0.0503 - val_loss: 0.0169 - val_mae: 0.0702
# Epoch 280/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0500
# Epoch 280: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0063 - mae: 0.0500 - val_loss: 0.0178 - val_mae: 0.0714
# Epoch 281/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0498
# Epoch 281: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0063 - mae: 0.0498 - val_loss: 0.0177 - val_mae: 0.0707
# Epoch 282/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0498
# Epoch 282: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0063 - mae: 0.0498 - val_loss: 0.0171 - val_mae: 0.0700
# Epoch 283/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0063 - mae: 0.0496
# Epoch 283: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0063 - mae: 0.0496 - val_loss: 0.0169 - val_mae: 0.0698
# Epoch 284/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0062 - mae: 0.0496
# Epoch 284: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0062 - mae: 0.0495 - val_loss: 0.0166 - val_mae: 0.0693
# Epoch 285/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0062 - mae: 0.0493
# Epoch 285: val_loss did not improve from 0.01598
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0062 - mae: 0.0493 - val_loss: 0.0161 - val_mae: 0.0689
# Epoch 286/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0062 - mae: 0.0493
# Epoch 286: val_loss improved from 0.01598 to 0.01579, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 35ms/step - loss: 0.0062 - mae: 0.0493 - val_loss: 0.0158 - val_mae: 0.0682
# Epoch 287/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0061 - mae: 0.0492
# Epoch 287: val_loss did not improve from 0.01579
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0061 - mae: 0.0492 - val_loss: 0.0162 - val_mae: 0.0689
# Epoch 288/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0061 - mae: 0.0492
# Epoch 288: val_loss did not improve from 0.01579
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0061 - mae: 0.0492 - val_loss: 0.0162 - val_mae: 0.0686
# Epoch 289/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0061 - mae: 0.0491
# Epoch 289: val_loss did not improve from 0.01579
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0061 - mae: 0.0491 - val_loss: 0.0160 - val_mae: 0.0682
# Epoch 290/300
# 152/152 [==============================] - ETA: 0s - loss: 0.0061 - mae: 0.0492
# Epoch 290: val_loss did not improve from 0.01579
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0061 - mae: 0.0492 - val_loss: 0.0164 - val_mae: 0.0699
# Epoch 291/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0062 - mae: 0.0493
# Epoch 291: val_loss improved from 0.01579 to 0.01576, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0062 - mae: 0.0493 - val_loss: 0.0158 - val_mae: 0.0678
# Epoch 292/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0061 - mae: 0.0491
# Epoch 292: val_loss did not improve from 0.01576
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0061 - mae: 0.0491 - val_loss: 0.0168 - val_mae: 0.0698
# Epoch 293/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0061 - mae: 0.0489
# Epoch 293: val_loss improved from 0.01576 to 0.01568, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0061 - mae: 0.0489 - val_loss: 0.0157 - val_mae: 0.0677
# Epoch 294/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0061 - mae: 0.0488
# Epoch 294: val_loss did not improve from 0.01568
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0061 - mae: 0.0488 - val_loss: 0.0165 - val_mae: 0.0684
# Epoch 295/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0061 - mae: 0.0488
# Epoch 295: val_loss did not improve from 0.01568
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0061 - mae: 0.0488 - val_loss: 0.0158 - val_mae: 0.0675
# Epoch 296/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0060 - mae: 0.0487
# Epoch 296: val_loss did not improve from 0.01568
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0061 - mae: 0.0488 - val_loss: 0.0162 - val_mae: 0.0685
# Epoch 297/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0060 - mae: 0.0487
# Epoch 297: val_loss did not improve from 0.01568
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0060 - mae: 0.0487 - val_loss: 0.0161 - val_mae: 0.0680
# Epoch 298/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0060 - mae: 0.0486
# Epoch 298: val_loss improved from 0.01568 to 0.01543, saving model to Solar_UNET.h5
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0060 - mae: 0.0486 - val_loss: 0.0154 - val_mae: 0.0678
# Epoch 299/300
# 151/152 [============================>.] - ETA: 0s - loss: 0.0077 - mae: 0.0539
# Epoch 299: val_loss did not improve from 0.01543
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0077 - mae: 0.0539 - val_loss: 0.0185 - val_mae: 0.0748
# Epoch 300/300
# 150/152 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0503
# Epoch 300: val_loss did not improve from 0.01543
# 152/152 [==============================] - 5s 34ms/step - loss: 0.0064 - mae: 0.0503 - val_loss: 0.0170 - val_mae: 0.0705
# Training completed in 1546.29 seconds (25.77 minutes)

# %%
# Plot the loss diagram
plt.figure(figsize=(10, 6))
plt.plot(results.history['loss'], label='Training Loss')
plt.plot(results.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('Training and Validation Loss.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
# Plot the accuracy diagram
plt.figure(figsize=(10, 6))
plt.plot(results.history['mae'], label='Mean Absolute Error')
plt.plot(results.history['val_mae'], label='Validation Mean Absolute Error')
plt.title('Training and Validation Mean Absolute Error')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.savefig('Training and Validation Mean Absolute Error.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
solar_max = np.max(solar_values)
solar_min = np.min(solar_values)
print(solar_max)
print(solar_min)
# Out:
# 1045434.44
# 0.0

# %%
start_time = time.time()
y_pred1 = model.predict(x_test)

end_time = time.time()
x_test_time_seconds = end_time - start_time
x_test_time_minutes = x_test_time_seconds / 60

print("x_test_Prediction completed in {:.2f} seconds ({:.2f} minutes)".format(x_test_time_seconds, x_test_time_minutes))
# Out:
# 48/48 [==============================] - 1s 17ms/step
# x_test_Prediction completed in 1.18 seconds (0.02 minutes)

# %%
start_time = time.time()
y_train_pred =  model.predict(x_train)

end_time = time.time()
x_train_time_seconds = end_time - start_time
x_train_time_minutes = x_train_time_seconds / 60

print("x_train_Prediction completed in {:.2f} seconds ({:.2f} minutes)".format(x_train_time_seconds,x_train_time_minutes))
# Out:
# 152/152 [==============================] - 1s 9ms/step
# x_train_Prediction completed in 2.07 seconds (0.03 minutes)

# %%
y_pred1 = model.predict(x_test)
y_pred = y_pred1 * (solar_max - solar_min) + solar_min
y_test2 = y_test * (solar_max - solar_min) + solar_min
# Out:
# 48/48 [==============================] - 1s 14ms/step

# %%
start_time = time.time()
y_train_pred =  model.predict(x_data_dsm)

end_time = time.time()
x_data_dsm_time_seconds = end_time - start_time
x_data_dsm_time_minutes = x_data_dsm_time_seconds / 60

print("x_data_dsm_Prediction completed in {:.2f} seconds ({:.2f} minutes)".format(x_data_dsm_time_seconds,x_data_dsm_time_minutes))
# Out:
# 237/237 [==============================] - 2s 8ms/step
# x_data_dsm_Prediction completed in 2.86 seconds (0.05 minutes)

# %%
# Flatten the arrays
y_test2_flat = y_test2.flatten()
y_pred_flat = y_pred.flatten()

# Calculate R^2
r2 = r2_score(y_test2_flat, y_pred_flat)

# %%
# Calculate R^2 for training data
y_train_pred = model.predict(x_train)
y_train_pred2 = y_train_pred * (solar_max - solar_min) + solar_min
y_train2 = y_train * (solar_max - solar_min) + solar_min
# # Flatten the arrays
y_train_pred2_flat = y_train_pred2.flatten()
y_train2_flat = y_train2.flatten()

# Calculate R^2 for training data
r2_train = r2_score(y_train2_flat, y_train_pred2_flat)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Flatten the arrays
y_train_denormalized_flat =y_train_pred2.flatten()
y_train_pred_flat = y_train2.flatten()

# Calculate metrics for training data
train_rmse = np.sqrt(mean_squared_error(y_train_denormalized_flat, y_train_pred_flat))
train_mae = mean_absolute_error(y_train_denormalized_flat, y_train_pred_flat)
train_r2 = r2_score(y_train_denormalized_flat, y_train_pred_flat)

# Flatten the arrays for test data as well
y_test_denormalized_flat = y_test2.flatten()
y_test_pred_flat = y_pred.flatten()

# Calculate metrics for test data
test_rmse = np.sqrt(mean_squared_error(y_test_denormalized_flat, y_test_pred_flat))
test_mae = mean_absolute_error(y_test_denormalized_flat, y_test_pred_flat)
test_r2 = r2_score(y_test_denormalized_flat, y_test_pred_flat)

# Print or use the metrics as needed
print(f"Train RMSE: {train_rmse:.4f}")
print(f"Train MAE: {train_mae:.4f}")
print(f"Train R2: {train_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MAE: {test_mae:.4f}")
print(f"Test R2: {test_r2:.4f}")
# Out:
# Train RMSE: 108357.2578
# Train MAE: 68781.1406
# Train R2: 0.8762
# Test RMSE: 138524.6250
# Test MAE: 79422.3125
# Test R2: 0.8143

# %%
scores = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Test loss: 0.03611369431018829
# Test accuracy: 0.09131297469139099
